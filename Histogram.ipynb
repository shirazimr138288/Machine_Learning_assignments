# %%
a=input("Input your dream text")
histogram={}
for char in text :
    if char in histogram :
         histogram [char] += 1
    else :
         histogram[char] = 1
print( histogram)
# Out:
# Input your dream text Miss.Lawyer Paria Shirazi
# {'M': 1, 'i': 4, 's': 2, '.': 1, ' ': 3, 'L': 1, 'a': 4, 'w': 1, 'y': 1, 'e': 1, 'r': 3, 'P': 1, 'S': 1, 'h': 1, 'z': 1}
